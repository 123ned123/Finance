# %%
from __future__ import annotations

import argparse
import csv
import sys
import time
from datetime import datetime, timezone
from typing import Dict, Optional

try:
    import yfinance as yf
except Exception as e:
    print("Error: yfinance is required. Install with: pip install yfinance", file=sys.stderr)
    raise

# Friendly name -> default ticker helpers
NICKNAMES: Dict[str, str] = {
    "google": "GOOGL",     # Alphabet Class A
    "alphabet": "GOOGL",
    "googl": "GOOGL",
    "goog": "GOOG",        # Alphabet Class C
    "apple": "AAPL",
    "microsoft": "MSFT",
    "tesla": "TSLA",
    "amazon": "AMZN",
    "meta": "META",
    "facebook": "META",
    "nvidia": "NVDA",
}

def resolve_ticker(user_input: str) -> str:
    key = user_input.strip().lower()
    return NICKNAMES.get(key, user_input.strip().upper())

def utc_now_iso() -> str:
    return datetime.now(timezone.utc).isoformat()

def fetch_quote(ticker: str) -> Optional[dict]:
    """
    Fetch a consolidated quote dict using yfinance with sensible fallbacks.
    Returns None if nothing could be fetched.
    """
    t = yf.Ticker(ticker)

    # Try to use fast_info (fastest, minimal overhead)
    last = bid = ask = prev_close = volume = None
    currency = exchange = short_name = market_state = None

    try:
        fi = t.fast_info
        # Some fields may be missing per ticker
        last = fi.get("last_price", None)
        bid = fi.get("bid", None)
        ask = fi.get("ask", None)
        prev_close = fi.get("previous_close", None)
        volume = fi.get("last_volume", None) or fi.get("volume", None)
        currency = fi.get("currency", None)
        exchange = fi.get("exchange", None)
    except Exception:
        pass

    # Supplement with basic_info if available
    try:
        info = getattr(t, "info", {}) or {}
        currency = currency or info.get("currency")
        exchange = exchange or info.get("fullExchangeName") or info.get("exchange")
        short_name = info.get("shortName") or info.get("longName")
        market_state = info.get("marketState")
        if prev_close is None:
            prev_close = info.get("regularMarketPreviousClose")
        if last is None:
            last = info.get("regularMarketPrice")
        if bid is None:
            bid = info.get("bid")
        if ask is None:
            ask = info.get("ask")
        if volume is None:
            volume = info.get("regularMarketVolume")
    except Exception:
        pass

    # If still missing 'last', try minute history as a final fallback
    if last is None:
        try:
            df = t.history(period="1d", interval="1m", prepost=True)
            if df is not None and not df.empty:
                last = float(df["Close"].iloc[-1])
        except Exception:
            pass

    # If still nothing, fail
    if last is None and bid is None and ask is None and prev_close is None:
        return None

    # Compute change/percent if possible
    change = None
    change_pct = None
    try:
        if last is not None and prev_close not in (None, 0):
            change = float(last) - float(prev_close)
            change_pct = (change / float(prev_close)) * 100.0
    except Exception:
        pass

    return {
        "last": _to_float(last),
        "bid": _to_float(bid),
        "ask": _to_float(ask),
        "prev_close": _to_float(prev_close),
        "change": _to_float(change),
        "change_pct": _to_float(change_pct),
        "volume": _to_int(volume),
        "currency": currency,
        "exchange": exchange,
        "short_name": short_name,
        "market_state": market_state,
    }

def _to_float(x):
    try:
        return None if x is None else float(x)
    except Exception:
        return None

def _to_int(x):
    try:
        return None if x is None else int(x)
    except Exception:
        return None

def run_forever(ticker: str, interval: int, out_csv: str, quiet: bool):
    # Prepare CSV and write header if needed
    write_header = False
    try:
        with open(out_csv, "r", encoding="utf-8") as _:
            pass
    except FileNotFoundError:
        write_header = True

    with open(out_csv, "a", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        if write_header:
            writer.writerow([
                "timestamp_utc",
                "ticker",
                "last",
                "bid",
                "ask",
                "change",
                "change_pct",
                "prev_close",
                "volume",
                "market_state",
                "currency",
                "exchange",
                "short_name",
            ])

        while True:
            ts = utc_now_iso()
            q = None
            err = None
            try:
                q = fetch_quote(ticker)
            except Exception as e:
                err = e

            if q:
                writer.writerow([
                    ts,
                    ticker,
                    _fmt(q["last"]),
                    _fmt(q["bid"]),
                    _fmt(q["ask"]),
                    _fmt(q["change"]),
                    _fmt(q["change_pct"]),
                    _fmt(q["prev_close"]),
                    q.get("volume") if q.get("volume") is not None else "",
                    q.get("market_state") or "",
                    q.get("currency") or "",
                    q.get("exchange") or "",
                    q.get("short_name") or "",
                ])
                f.flush()
                if not quiet:
                    _print_console(ts, ticker, q)
            else:
                msg = f"{ts}  {ticker}: quote unavailable"
                if err:
                    msg += f" ({err})"
                print(msg, file=sys.stderr)

            time.sleep(max(1, interval))


def _fmt(x):
    if x is None:
        return ""
    try:
        return f"{float(x):.6f}"
    except Exception:
        return str(x)

def _print_console(ts, ticker, q):
    last = q.get("last")
    chg = q.get("change")
    chgp = q.get("change_pct")
    bid = q.get("bid")
    ask = q.get("ask")
    mkt = q.get("market_state") or ""
    ccy = q.get("currency") or ""
    parts = [
        ts,
        f"{ticker}",
        f"last={_fmt(last)}",
        f"bid/ask={_fmt(bid)}/{_fmt(ask)}",
        f"Δ={_fmt(chg)} ({_fmt(chgp)}%)",
        f"{mkt} {ccy}".strip(),
    ]
    print("  ".join(p for p in parts if p))

def parse_args(argv=None):
    p = argparse.ArgumentParser(description="24/7 quote logger using yfinance")
    p.add_argument("--ticker", default="GOOGL", help="Ticker symbol or nickname (default: GOOGL). Examples: MSFT, AAPL, TSLA, google")
    p.add_argument("--interval", type=int, default=30, help="Polling interval in seconds (default: 30)")
    p.add_argument("--out", default="quotes.csv", help="CSV output path (default: quotes.csv)")
    p.add_argument("--quiet", action="store_true", help="Suppress console prints (still writes CSV)")
    return p.parse_args(argv)

def main(argv=None):
    args = parse_args(argv)
    ticker = resolve_ticker(args.ticker)
    print(f"Starting watcher for {ticker} every {args.interval}s. Writing to {args.out}. Press Ctrl+C to stop.", file=sys.stderr)
    run_forever(ticker, args.interval, args.out, args.quiet)

# %%
aapl = yf.Ticker("aapl")
news = aapl.news

news
# Out:
# [{'id': 'a6c02fd5-7b13-33fa-878c-4ba88f6f2f3d',
#   'content': {'id': 'a6c02fd5-7b13-33fa-878c-4ba88f6f2f3d',
#    'contentType': 'VIDEO',
#    'title': 'Nvidia, Tesla dominate Dec. trading as 2025 options demand surges',
#    'description': '<p>Cboe vice president of market intelligence Henry Schwartz joins Market Domination with Yahoo Finance Data and Markets Editor <a data-i13n="cpos:1;pos:1" href="https://finance.yahoo.com/author/jared-blikre/">Jared Blikre</a> to discuss the state of the options landscape.</p>\n<p>Watch the video above to hear Schwartz\'s outlook for the options market in 2026.</p>\n<p>To watch more expert insights and analysis on the latest market action, check out more <a data-i13n="cpos:2;pos:1" href="https://finance.yahoo.com/videos/series/market-domination/">Market Domination</a>.</p>',
#    'summary': "Cboe vice president of market intelligence Henry Schwartz joins Market Domination with Yahoo Finance Data and Markets Editor Jared Blikre to discuss the state of the options landscape. Watch the video above to hear Schwartz's outlook for the options market in 2026. To watch more expert insights and analysis on the latest market action, check out more Market Domination.",
#    'pubDate': '2025-12-19T21:48:29Z',
#    'displayTime': '',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-12/75ff7d70-dd22-11f0-bf3b-0fd7f855de24',
#     'originalWidth': 5020,
#     'originalHeight': 2826,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/lQjeLbajcimwLPWH6yrTKw--~B/aD0yODI2O3c9NTAyMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-12/75ff7d70-dd22-11f0-bf3b-0fd7f855de24',
#       'width': 5020,
#       'height': 2826,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/I7UtGY3DXe3T1lPp.fSezQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-12/75ff7d70-dd22-11f0-bf3b-0fd7f855de24',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance Video',
#     'url': 'https://finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/video/nvidia-tesla-dominate-dec-trading-214829316.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/video/nvidia-tesla-dominate-dec-trading-214829316.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': True},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'aea1a51b-cf54-3071-9895-4621028caa76',
#   'content': {'id': 'aea1a51b-cf54-3071-9895-4621028caa76',
#    'contentType': 'VIDEO',
#    'title': "Strategist says this Mag 7 name is the 'sneakiest' AI play",
#    'description': '<p>Ahead of 2026\'s kick-off, investors are putting heavy consideration into <a data-i13n="cpos:1;pos:1" href="https://finance.yahoo.com/video/2026-outlook-ai-revolution-comes-145311180.html">how to play the AI trade</a>. B. Riley Wealth chief market strategist Art Hogan joins Opening Bid with <a data-i13n="cpos:2;pos:1" href="https://finance.yahoo.com/author/brian-sozzi/">Brian Sozzi</a> to talk about his expectations for the Magnificent Seven and the broader AI trade.</p>\n<p>To watch more expert insights and analysis on the latest market action, check out more <a data-i13n="cpos:3;pos:1" href="https://finance.yahoo.com/videos/series/opening-bid/">Opening Bid</a>.</p>',
#    'summary': "Ahead of 2026's kick-off, investors are putting heavy consideration into how to play the AI trade. B. Riley Wealth chief market strategist Art Hogan joins Opening Bid with Brian Sozzi to talk about his expectations for the Magnificent Seven and the broader AI trade. To watch more expert insights and analysis on the latest market action, check out more Opening Bid.",
#    'pubDate': '2025-12-19T17:30:00Z',
#    'displayTime': '',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-12/cd837530-dcf8-11f0-bafd-d5c6ccdfd53a',
#     'originalWidth': 5895,
#     'originalHeight': 3320,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/il0_Dy7Kjb38XX_4zxypOg--~B/aD0zMzIwO3c9NTg5NTthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-12/cd837530-dcf8-11f0-bafd-d5c6ccdfd53a',
#       'width': 5895,
#       'height': 3320,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/JMYAVQoLkRGC57RFHTFl_w--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-12/cd837530-dcf8-11f0-bafd-d5c6ccdfd53a',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance Video',
#     'url': 'https://finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/video/strategist-says-mag-7-name-173000008.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/video/strategist-says-mag-7-name-173000008.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': True},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'eb38dc58-7c08-384c-bf53-d95527a704c3',
#   'content': {'id': 'eb38dc58-7c08-384c-bf53-d95527a704c3',
#    'contentType': 'STORY',
#    'title': 'Analysts Have a Moderate Buy Rating on Apple Inc. (AAPL)',
#    'description': '',
#    'summary': 'Apple Inc. (NASDAQ:AAPL) is among the 14 Best S&P 500 Stocks to Buy Now. On December 15, JPMorgan analyst Samik Chatterjee maintained an Overweight rating on the stock with a share price target of $305, a reaffirmation of an earlier update on October 31. The adjustment follows Citi analyst Atif Malik lifting his price target […]',
#    'pubDate': '2025-12-20T11:56:31Z',
#    'displayTime': '2025-12-20T11:56:31Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/insidermonkey.com/410ac07c4c90786d8592963501a2ed84',
#     'originalWidth': 1456,
#     'originalHeight': 816,
#     'caption': 'Analysts Have a Moderate Buy Rating on Apple Inc. (AAPL)',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ZW3fq6JkBYqEx9N2Vum6qQ--~B/aD04MTY7dz0xNDU2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/410ac07c4c90786d8592963501a2ed84',
#       'width': 1456,
#       'height': 816,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/Lc51vPFvh_63B_mHSkS49Q--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/410ac07c4c90786d8592963501a2ed84',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Insider Monkey',
#     'url': 'http://www.insidermonkey.com'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/analysts-moderate-buy-rating-apple-115631787.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/analysts-moderate-buy-rating-apple-115631787.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'aa3cecef-6c58-481b-9447-ac82d03c8fe4',
#   'content': {'id': 'aa3cecef-6c58-481b-9447-ac82d03c8fe4',
#    'contentType': 'STORY',
#    'title': "'Childminding is an exciting, AI-proof way to make a good living'",
#    'description': '',
#    'summary': "Brett Wigdortz grew Teach First into the UK's biggest graduate recruiter and is now leading Tiney's bid to become a success as a leading  childminder agency.",
#    'pubDate': '2025-12-20T06:00:14Z',
#    'displayTime': '2025-12-20T06:00:14Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-12/0ee00910-db52-11f0-bfff-e05dabc968ff',
#     'originalWidth': 6000,
#     'originalHeight': 4000,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/iVdD78c0FghANDZq65twjg--~B/aD00MDAwO3c9NjAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-12/0ee00910-db52-11f0-bfff-e05dabc968ff',
#       'width': 6000,
#       'height': 4000,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/BeMX7j2zMTVdSyd7ZM4JzQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-12/0ee00910-db52-11f0-bfff-e05dabc968ff',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance UK',
#     'url': 'http://uk.finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://uk.finance.yahoo.com/news/childminding-business-career-tiney-060014069.html',
#     'site': 'finance',
#     'region': 'GB',
#     'lang': 'en-GB'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/childminding-business-career-tiney-060014069.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '8c220dd6-74d5-3970-9b87-7fcf28ccabfe',
#   'content': {'id': '8c220dd6-74d5-3970-9b87-7fcf28ccabfe',
#    'contentType': 'STORY',
#    'title': '5 predictions for tech and AI in 2026 from mega-bull Dan Ives',
#    'description': '',
#    'summary': 'Wedbush analyst Dan Ives reveals his top tech and AI predictions for the coming year, laying out his most bullish calls for companies and sectors.',
#    'pubDate': '2025-12-20T01:11:28Z',
#    'displayTime': '2025-12-20T01:11:28Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/business_insider_articles_888/4d6b6ec0551a2649edfee021321f2067',
#     'originalWidth': 4224,
#     'originalHeight': 3168,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/9BRiCvqqK8mrGs9x1b5Saw--~B/aD0zMTY4O3c9NDIyNDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/business_insider_articles_888/4d6b6ec0551a2649edfee021321f2067',
#       'width': 4224,
#       'height': 3168,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/UtL2SxtmXxqdbQ5XoSA3Yw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/business_insider_articles_888/4d6b6ec0551a2649edfee021321f2067',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Business Insider',
#     'url': 'https://www.businessinsider.com/'},
#    'canonicalUrl': {'url': 'https://www.businessinsider.com/ai-outlook-2026-tech-stocks-telsa-robotaxis-google-apple-nebius-2025-12',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/5-predictions-tech-ai-2026-171128505.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '83faeafe-1349-355b-ac46-f730bbf4bc5f',
#   'content': {'id': '83faeafe-1349-355b-ac46-f730bbf4bc5f',
#    'contentType': 'STORY',
#    'title': '‘I don’t know how much my wife earns’: I’m 63 with $6.4 million in stocks, mostly Apple. Will I get punished on taxes?',
#    'description': '',
#    'summary': '“Each of our properties are worth over $1 million.”',
#    'pubDate': '2025-12-19T22:30:00Z',
#    'displayTime': '2025-12-19T22:30:00Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/marketwatch_hosted_869/528d8f3cb1677881b5ffa1ace6e3974e',
#     'originalWidth': 1280,
#     'originalHeight': 640,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/q1LYVP7qoa7qXuT6WWqmww--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/marketwatch_hosted_869/528d8f3cb1677881b5ffa1ace6e3974e',
#       'width': 1280,
#       'height': 640,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/viFCxGE.UrJLGydXYhW9iw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/marketwatch_hosted_869/528d8f3cb1677881b5ffa1ace6e3974e',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'MarketWatch',
#     'url': 'http://www.marketwatch.com/'},
#    'canonicalUrl': {'url': 'https://www.marketwatch.com/story/i-dont-know-how-much-my-wife-earns-im-63-with-6-4-million-in-stocks-mostly-apple-will-i-get-punished-on-taxes-41c18f41',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/don-t-know-much-wife-124800562.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '1543cda8-d7ab-3f93-875a-1af97e564e19',
#   'content': {'id': '1543cda8-d7ab-3f93-875a-1af97e564e19',
#    'contentType': 'STORY',
#    'title': 'Get Ready for New Chip Shortages. Micron’s Success All but Guarantees It.',
#    'description': '',
#    'summary': 'Micron’s blowout earnings report shows memory chips are in hot demand. The coming crunch could exceed the Covid-era chip shortage.',
#    'pubDate': '2025-12-19T21:38:00Z',
#    'displayTime': '2025-12-19T21:38:00Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/1543cda8-d7ab-3f93-875a-1af97e564e19/get-ready-for-new-chip.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/Barrons.com/d734190101cac4d53dde2da84402da79',
#     'originalWidth': 1280,
#     'originalHeight': 640,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/oqjdXYVlspaoEK1H846lrg--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/d734190101cac4d53dde2da84402da79',
#       'width': 1280,
#       'height': 640,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/oi_.D1vW_l1SEQ5TQMlSaw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/Barrons.com/d734190101cac4d53dde2da84402da79',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Barrons.com',
#     'url': 'http://www.barrons.com/'},
#    'canonicalUrl': {'url': 'https://www.barrons.com/articles/chip-shortages-loom-micron-earnings-show-supply-squeeze-624a0a0b?siteid=yhoof2&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '1ea65ad6-71ea-3962-a1dc-765342474b9b',
#   'content': {'id': '1ea65ad6-71ea-3962-a1dc-765342474b9b',
#    'contentType': 'STORY',
#    'title': 'Mag 7 Stocks Keep Bouncing Back',
#    'description': '',
#    'summary': 'Big Tech stocks rallied back again on Friday. The Roundhill Magnificent Seven ETF was up 0.7% after surging nearly 2% yesterday. The group of megacap tech stocks rebounded sharply from a 2.2% drop on Wednesday.',
#    'pubDate': '2025-12-19T20:21:04Z',
#    'displayTime': '2025-12-19T20:21:04Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/1ea65ad6-71ea-3962-a1dc-765342474b9b/mag-7-stocks-keep-bouncing.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/Barrons.com/12ea0f43d8f8307249a68d1cb2e0587e',
#     'originalWidth': 320,
#     'originalHeight': 65,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/_kc6REYMS1JrAuV5bYtjfA--~B/aD02NTt3PTMyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/Barrons.com/12ea0f43d8f8307249a68d1cb2e0587e',
#       'width': 320,
#       'height': 65,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/Eugzn1_7mDocWpeqoc2fFg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/Barrons.com/12ea0f43d8f8307249a68d1cb2e0587e',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Barrons.com',
#     'url': 'http://www.barrons.com/'},
#    'canonicalUrl': {'url': 'https://www.barrons.com/livecoverage/stock-market-news-today-121925/card/mag-7-stocks-keep-bouncing-back-kIzX9VHvNcYKWI3QmJHC?siteid=yhoof2&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '8ca88270-7389-377c-999c-557f1947241f',
#   'content': {'id': '8ca88270-7389-377c-999c-557f1947241f',
#    'contentType': 'STORY',
#    'title': 'Jim Cramer Says “We Need More Winners, But It’s Just Alphabet”',
#    'description': '',
#    'summary': 'Alphabet Inc. (NASDAQ:GOOGL) is one of the stocks Jim Cramer recently discussed. Cramer highlighted the company’s deal with Apple during the episode, as he said: “Almost every single tech company I follow has a monstrous set of rivals spending tens of billions of dollars to dominate the particular industry. Now, in one case, that spending […]',
#    'pubDate': '2025-12-19T19:14:47Z',
#    'displayTime': '2025-12-19T19:14:47Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/insidermonkey.com/af2bb6bdbc4f56cfaf197a2118a94cf1',
#     'originalWidth': 1920,
#     'originalHeight': 1440,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/5i30it7RT8AZBHZBJSSzig--~B/aD0xNDQwO3c9MTkyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/insidermonkey.com/af2bb6bdbc4f56cfaf197a2118a94cf1',
#       'width': 1920,
#       'height': 1440,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/yqglgDyk7EEaoAgem2eUNQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/af2bb6bdbc4f56cfaf197a2118a94cf1',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Insider Monkey',
#     'url': 'http://www.insidermonkey.com'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/jim-cramer-says-more-winners-191447373.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/jim-cramer-says-more-winners-191447373.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'a3519738-7c05-35f6-9633-f60762211131',
#   'content': {'id': 'a3519738-7c05-35f6-9633-f60762211131',
#    'contentType': 'STORY',
#    'title': 'Visa, Mastercard make a global push for mobile wallets',
#    'description': '',
#    'summary': "The card networks have entered a series of partnerships in Europe and Asia amid signs of growing demand and Apple's waning control over the underlying technology.",
#    'pubDate': '2025-12-19T18:40:22Z',
#    'displayTime': '2025-12-19T18:40:22Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/american_banker_655/712e36914f4d23e42fb4da9abf71beef',
#     'originalWidth': 1020,
#     'originalHeight': 574,
#     'caption': 'chart visualization',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/M60naO6.5feQ0ToOj_VW3g--~B/aD01NzQ7dz0xMDIwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/american_banker_655/712e36914f4d23e42fb4da9abf71beef',
#       'width': 1020,
#       'height': 574,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/wupgtQWjUB3cfEz6NH6Mzg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/american_banker_655/712e36914f4d23e42fb4da9abf71beef',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'American Banker',
#     'url': 'https://www.americanbanker.com/'},
#    'canonicalUrl': {'url': 'https://www.americanbanker.com/payments/news/visa-and-mastercard-push-mobile-wallet-strategies',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/visa-mastercard-global-push-mobile-184022817.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}}]

# %%
aapl = yf.Ticker("GOOG")
news = aapl.news

news
# Out:
# [{'id': '18ff5232-3703-44b7-a548-65c68fbea3cc',
#   'content': {'id': '18ff5232-3703-44b7-a548-65c68fbea3cc',
#    'contentType': 'STORY',
#    'title': 'What’s next for EVs after a year of unraveling',
#    'description': '',
#    'summary': 'In 2026, a hybrid approach is the recalibration the auto industry is banking on.',
#    'pubDate': '2025-12-20T11:00:45Z',
#    'displayTime': '2025-12-20T12:36:27Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-12/57fd4a70-dcee-11f0-9f57-29827ad768a5',
#     'originalWidth': 8034,
#     'originalHeight': 5347,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/UxJm1q09HbjiyLKI2uqyYw--~B/aD01MzQ3O3c9ODAzNDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-12/57fd4a70-dcee-11f0-9f57-29827ad768a5',
#       'width': 8034,
#       'height': 5347,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/DPKZhoNXvRZrD4bd9Zpeug--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-12/57fd4a70-dcee-11f0-9f57-29827ad768a5',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance',
#     'url': 'http://finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/whats-next-for-evs-after-a-year-of-unraveling-110045894.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/whats-next-for-evs-after-a-year-of-unraveling-110045894.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': True},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'aea1a51b-cf54-3071-9895-4621028caa76',
#   'content': {'id': 'aea1a51b-cf54-3071-9895-4621028caa76',
#    'contentType': 'VIDEO',
#    'title': "Strategist says this Mag 7 name is the 'sneakiest' AI play",
#    'description': '<p>Ahead of 2026\'s kick-off, investors are putting heavy consideration into <a data-i13n="cpos:1;pos:1" href="https://finance.yahoo.com/video/2026-outlook-ai-revolution-comes-145311180.html">how to play the AI trade</a>. B. Riley Wealth chief market strategist Art Hogan joins Opening Bid with <a data-i13n="cpos:2;pos:1" href="https://finance.yahoo.com/author/brian-sozzi/">Brian Sozzi</a> to talk about his expectations for the Magnificent Seven and the broader AI trade.</p>\n<p>To watch more expert insights and analysis on the latest market action, check out more <a data-i13n="cpos:3;pos:1" href="https://finance.yahoo.com/videos/series/opening-bid/">Opening Bid</a>.</p>',
#    'summary': "Ahead of 2026's kick-off, investors are putting heavy consideration into how to play the AI trade. B. Riley Wealth chief market strategist Art Hogan joins Opening Bid with Brian Sozzi to talk about his expectations for the Magnificent Seven and the broader AI trade. To watch more expert insights and analysis on the latest market action, check out more Opening Bid.",
#    'pubDate': '2025-12-19T17:30:00Z',
#    'displayTime': '',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-12/cd837530-dcf8-11f0-bafd-d5c6ccdfd53a',
#     'originalWidth': 5895,
#     'originalHeight': 3320,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/il0_Dy7Kjb38XX_4zxypOg--~B/aD0zMzIwO3c9NTg5NTthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-12/cd837530-dcf8-11f0-bafd-d5c6ccdfd53a',
#       'width': 5895,
#       'height': 3320,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/JMYAVQoLkRGC57RFHTFl_w--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-12/cd837530-dcf8-11f0-bafd-d5c6ccdfd53a',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance Video',
#     'url': 'https://finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/video/strategist-says-mag-7-name-173000008.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/video/strategist-says-mag-7-name-173000008.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': True},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '21efdd73-59b7-33fc-8e84-fd1b3ad8eb99',
#   'content': {'id': '21efdd73-59b7-33fc-8e84-fd1b3ad8eb99',
#    'contentType': 'STORY',
#    'title': 'Next Data Center Roadblock For Google, Microsoft, Oracle, Meta Is On Main Street',
#    'description': '',
#    'summary': "The data centers critical to the nation's AI ambitions are spawning local political battles as rising energy costs frustrate communities. What investors need to know about data center NIMBYism.",
#    'pubDate': '2025-12-20T12:43:00Z',
#    'displayTime': '2025-12-20T12:43:00Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/21efdd73-59b7-33fc-8e84-fd1b3ad8eb99/next-data-center-roadblock.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/ibd.com/72ec9f6160960871d85d277d1857a137',
#     'originalWidth': 1000,
#     'originalHeight': 563,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/M529sf_I9CPsDnhDKbGTNQ--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/72ec9f6160960871d85d277d1857a137',
#       'width': 1000,
#       'height': 563,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/0G3vSw.Rme4Zzj2CmZsWPw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/ibd.com/72ec9f6160960871d85d277d1857a137',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': "Investor's Business Daily",
#     'url': 'http://www.investors.com/'},
#    'canonicalUrl': {'url': 'https://www.investors.com/news/data-centers-boom-backlash-electricity-rates-google-meta-amazon-microsoft/?src=A00220&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '75009171-693c-3ac9-97d6-8a98dfb8154f',
#   'content': {'id': '75009171-693c-3ac9-97d6-8a98dfb8154f',
#    'contentType': 'STORY',
#    'title': '3 Reasons to Buy Alphabet Stock in 2026 (And 1 to Sell)',
#    'description': '',
#    'summary': 'Alphabet had a dominant 2025 and looks to continue that success in 2026.',
#    'pubDate': '2025-12-20T12:20:00Z',
#    'displayTime': '2025-12-20T12:20:00Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/motleyfool.com/0a381813bdcbed28e7630fed613cabde',
#     'originalWidth': 1400,
#     'originalHeight': 1021,
#     'caption': "Image of a phone with Google's logo on it.",
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/pXr9dw5_5npONsYaUNcLMg--~B/aD0xMDIxO3c9MTQwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/0a381813bdcbed28e7630fed613cabde',
#       'width': 1400,
#       'height': 1021,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/yPokIjmWpurnwLpyG6oEhg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/motleyfool.com/0a381813bdcbed28e7630fed613cabde',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Motley Fool', 'url': 'http://www.fool.com/'},
#    'canonicalUrl': {'url': 'https://www.fool.com/investing/2025/12/20/3-reasons-to-buy-alphabet-stock-in-2026-and-1-to/',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/3-reasons-buy-alphabet-stock-122000710.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '960b248b-5188-3f15-bdaa-b5d70d586a2f',
#   'content': {'id': '960b248b-5188-3f15-bdaa-b5d70d586a2f',
#    'contentType': 'STORY',
#    'title': 'Alphabet Inc. (GOOGL) and Meta Working Together To Challenge Nvidia’s Market Dominance: Report',
#    'description': '',
#    'summary': 'Alphabet Inc. (NASDAQ:GOOGL) is among the 14 Best S&P 500 Stocks to Buy Now. According to a Reuters report on Wednesday, Google is working with Meta to make its AI chips better suited to running PyTorch, in a bid to challenge Nvidia’s dominance in the market. The initiative, called TorchTPU, aims to position Google’s Tensor […]',
#    'pubDate': '2025-12-20T11:56:25Z',
#    'displayTime': '2025-12-20T11:56:25Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/insidermonkey.com/b37705cc559a18e5d7c905152c29378c',
#     'originalWidth': 4860,
#     'originalHeight': 3240,
#     'caption': "Alphabet Inc. (GOOGL) and Meta Working Together To Challenge Nvidia's Market Dominance: Report",
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/PBR5Zaj1mx6Y5DBeaeMo_A--~B/aD0zMjQwO3c9NDg2MDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/insidermonkey.com/b37705cc559a18e5d7c905152c29378c',
#       'width': 4860,
#       'height': 3240,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/lpzghWm0c706VMSPzYaxBg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/b37705cc559a18e5d7c905152c29378c',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Insider Monkey',
#     'url': 'http://www.insidermonkey.com'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/alphabet-inc-googl-meta-working-115625127.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/alphabet-inc-googl-meta-working-115625127.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '025784ec-2c95-3674-adce-6a8fe4053809',
#   'content': {'id': '025784ec-2c95-3674-adce-6a8fe4053809',
#    'contentType': 'STORY',
#    'title': 'This Is What the World’s Smartest Minds Really Think About AI',
#    'description': '',
#    'summary': 'At a meeting that’s become the center of the tech universe, nerdy researchers partied on yachts and gathered on rooftops to trade gossip and compare notes. Everyone was feeling bubbly.',
#    'pubDate': '2025-12-20T02:00:00Z',
#    'displayTime': '2025-12-20T02:00:00Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/025784ec-2c95-3674-adce-6a8fe4053809/this-is-what-the-world%E2%80%99s.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/wsj.com/73992b6b7079bb2b519fc937e3d338b1',
#     'originalWidth': 1280,
#     'originalHeight': 640,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/.9N08JJaxFCl4Tz6uMTlpg--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/73992b6b7079bb2b519fc937e3d338b1',
#       'width': 1280,
#       'height': 640,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/lR.pe1nL0QV32.1FQE71lQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/wsj.com/73992b6b7079bb2b519fc937e3d338b1',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'The Wall Street Journal',
#     'url': 'http://www.wsj.com/'},
#    'canonicalUrl': {'url': 'https://www.wsj.com/tech/ai/ai-conference-neurips-ff6398df?siteid=yhoof2&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'd192ed75-1615-330b-a6c3-400023741ce5',
#   'content': {'id': 'd192ed75-1615-330b-a6c3-400023741ce5',
#    'contentType': 'STORY',
#    'title': '3 of the Best Artificial Intelligence (AI) Stocks to Buy for 2026',
#    'description': '',
#    'summary': "These tech giants are already massive, but that doesn't mean they've run out of opportunities to grow.",
#    'pubDate': '2025-12-20T01:58:00Z',
#    'displayTime': '2025-12-20T01:58:00Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/motleyfool.com/a9d15abd5222b14236755d41cac34dd2',
#     'originalWidth': 1400,
#     'originalHeight': 787,
#     'caption': 'A robot working in a warehouse and moving large packages.',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/fqMZD04HCsyZU3Y4ZipOjA--~B/aD03ODc7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/a9d15abd5222b14236755d41cac34dd2',
#       'width': 1400,
#       'height': 787,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/C7SxzqFaDihC9TGBA6gnYg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/motleyfool.com/a9d15abd5222b14236755d41cac34dd2',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Motley Fool', 'url': 'http://www.fool.com/'},
#    'canonicalUrl': {'url': 'https://www.fool.com/investing/2025/12/19/best-artificial-intelligence-ai-stocks-buy-2026/',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/3-best-artificial-intelligence-ai-015800360.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '8c220dd6-74d5-3970-9b87-7fcf28ccabfe',
#   'content': {'id': '8c220dd6-74d5-3970-9b87-7fcf28ccabfe',
#    'contentType': 'STORY',
#    'title': '5 predictions for tech and AI in 2026 from mega-bull Dan Ives',
#    'description': '',
#    'summary': 'Wedbush analyst Dan Ives reveals his top tech and AI predictions for the coming year, laying out his most bullish calls for companies and sectors.',
#    'pubDate': '2025-12-20T01:11:28Z',
#    'displayTime': '2025-12-20T01:11:28Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/business_insider_articles_888/4d6b6ec0551a2649edfee021321f2067',
#     'originalWidth': 4224,
#     'originalHeight': 3168,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/9BRiCvqqK8mrGs9x1b5Saw--~B/aD0zMTY4O3c9NDIyNDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/business_insider_articles_888/4d6b6ec0551a2649edfee021321f2067',
#       'width': 4224,
#       'height': 3168,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/UtL2SxtmXxqdbQ5XoSA3Yw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/business_insider_articles_888/4d6b6ec0551a2649edfee021321f2067',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Business Insider',
#     'url': 'https://www.businessinsider.com/'},
#    'canonicalUrl': {'url': 'https://www.businessinsider.com/ai-outlook-2026-tech-stocks-telsa-robotaxis-google-apple-nebius-2025-12',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/5-predictions-tech-ai-2026-171128505.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '3afae4ba-f355-37cf-8518-2827b00bc585',
#   'content': {'id': '3afae4ba-f355-37cf-8518-2827b00bc585',
#    'contentType': 'STORY',
#    'title': 'Breaking Down Oracle, the AI Trade, and the Outlook for Tech Earnings',
#    'description': '',
#    'summary': "Oracle's relationship with OpenAI has become a never-ending source of market angst, as the tie-in reminds many of questionable vendor-financing practices from the late 1990s. But is the caution overblown?",
#    'pubDate': '2025-12-19T22:39:00Z',
#    'displayTime': '2025-12-19T22:39:00Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/zacks.com/53d9a3fd304ab73d580828e5367313eb',
#     'originalWidth': 635,
#     'originalHeight': 400,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/rYP8VPOUfQj30jWv52_m5w--~B/aD00MDA7dz02MzU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/zacks.com/53d9a3fd304ab73d580828e5367313eb',
#       'width': 635,
#       'height': 400,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/AymTAiIL3zdJfPAt4g3XIg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/zacks.com/53d9a3fd304ab73d580828e5367313eb',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Zacks', 'url': 'http://www.zacks.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/breaking-down-oracle-ai-trade-223900137.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/breaking-down-oracle-ai-trade-223900137.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '91875d3d-902a-3141-b4b3-9ba2f69067cb',
#   'content': {'id': '91875d3d-902a-3141-b4b3-9ba2f69067cb',
#    'contentType': 'STORY',
#    'title': 'Why is Google Quietly Funneling Billions Into Bitcoin Miners?',
#    'description': '',
#    'summary': 'Google has quietly become a financial safety net for Bitcoin miners, providing at least $5 billion in credit support to help them pivot into Artificial Intelligence (AI). This isn’t a direct investment but something much smarter: a guarantee. Stocks of miners making this move, like Cipher and IREN, have surged ...',
#    'pubDate': '2025-12-19T22:32:29Z',
#    'displayTime': '2025-12-19T22:32:29Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/99bitcoins_us_315/f9b8a927f259c3ac58cdc1981d0bf73b',
#     'originalWidth': 350,
#     'originalHeight': 201,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/7nO1LWiTuIiRx8Bw9PyssQ--~B/aD0yMDE7dz0zNTA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/99bitcoins_us_315/f9b8a927f259c3ac58cdc1981d0bf73b',
#       'width': 350,
#       'height': 201,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/XSQDCsA_LfMAgRqRxuLzgw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/99bitcoins_us_315/f9b8a927f259c3ac58cdc1981d0bf73b',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': '99bitcoins', 'url': 'https://99bitcoins.com/'},
#    'canonicalUrl': {'url': 'https://99bitcoins.com/news/bitcoin-btc/why-is-google-quietly-funneling-billions-into-bitcoin-miners/',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/why-google-quietly-funneling-billions-223229158.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}}]

# %%
aapl = yf.Ticker("qqq")
news = aapl.news

news
# Out:
# [{'id': '6d5638d5-d52d-38b2-a278-5694b038fc4e',
#   'content': {'id': '6d5638d5-d52d-38b2-a278-5694b038fc4e',
#    'contentType': 'STORY',
#    'title': 'Is IVV or QQQ a Better Choice for Investors? How These Popular ETFs Compare on Risk and Returns',
#    'description': '',
#    'summary': "Expense ratio, sector mix, and yield set these two ETFs apart. See how their differences may shape your portfolio's risk and income profile.",
#    'pubDate': '2025-12-20T12:20:06Z',
#    'displayTime': '2025-12-20T12:20:06Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/motleyfool.com/6b28a065be0b5031477267afbc8e62a9',
#     'originalWidth': 1401,
#     'originalHeight': 1251,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Np9o3bh8VC1sVtimeVtyug--~B/aD0xMjUxO3c9MTQwMTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/6b28a065be0b5031477267afbc8e62a9',
#       'width': 1401,
#       'height': 1251,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/o.fMu5WMPr6k9.u2ROusfQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/motleyfool.com/6b28a065be0b5031477267afbc8e62a9',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Motley Fool', 'url': 'http://www.fool.com/'},
#    'canonicalUrl': {'url': 'https://www.fool.com/coverage/etfs/2025/12/20/is-ivv-or-qqq-a-better-choice-for-investors-how-these-popular-etfs-compare-on-risk-and-returns/',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/ivv-qqq-better-choice-investors-122006887.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '9726d4c8-b1b5-3108-9de6-9986d8b2f254',
#   'content': {'id': '9726d4c8-b1b5-3108-9de6-9986d8b2f254',
#    'contentType': 'STORY',
#    'title': 'This ETF Is Set To Beat the S&P 500 For the Third Year in a Row. Can It Do Again in 2026?',
#    'description': '',
#    'summary': 'The Invesco QQQ Trust has been one of the best ETFs on the market.',
#    'pubDate': '2025-12-20T00:05:00Z',
#    'displayTime': '2025-12-20T00:05:00Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/motleyfool.com/de92473af6bbb076bf5a69a89593a3f8',
#     'originalWidth': 1200,
#     'originalHeight': 675,
#     'caption': 'The word "ETF" against an iridescent background.',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/dAa37a2OxTZcIRJ_FXYxMw--~B/aD02NzU7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/de92473af6bbb076bf5a69a89593a3f8',
#       'width': 1200,
#       'height': 675,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/2QMoPvMcukteSUMx.0j1RA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/motleyfool.com/de92473af6bbb076bf5a69a89593a3f8',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Motley Fool', 'url': 'http://www.fool.com/'},
#    'canonicalUrl': {'url': 'https://www.fool.com/investing/2025/12/19/this-etf-has-beaten-the-sp-500-three-years-in-a-ro/',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/etf-set-beat-p-500-000500303.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'e04df7be-a617-3b73-ad84-c88b7db52109',
#   'content': {'id': 'e04df7be-a617-3b73-ad84-c88b7db52109',
#    'contentType': 'STORY',
#    'title': 'Exchange-Traded Funds Higher as US Equities Rise After Midday',
#    'description': '',
#    'summary': 'Broad Market Indicators Broad-market exchange-traded funds IWM and IVV rose. Actively traded Inve',
#    'pubDate': '2025-12-19T18:09:35Z',
#    'displayTime': '2025-12-19T18:09:35Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': None,
#    'provider': {'displayName': 'MT Newswires',
#     'url': 'https://www.mtnewswires.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/exchange-traded-funds-higher-us-180935480.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/exchange-traded-funds-higher-us-180935480.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': True,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '1573dcac-37f3-3f13-8653-be4b9264d926',
#   'content': {'id': '1573dcac-37f3-3f13-8653-be4b9264d926',
#    'contentType': 'STORY',
#    'title': 'The Nasdaq-100 ETF Just Flashed a Bearish Chart Signal. Here’s What Happens Next.',
#    'description': '',
#    'summary': 'It could be tough sledding for QQQ this Santa Claus season, says our top chart strategist, as profit-taking sweeps markets into a technical downtrend.',
#    'pubDate': '2025-12-19T16:09:23Z',
#    'displayTime': '2025-12-19T16:09:23Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/barchart_com_477/504dba31bff02fcd8f8d5c2ba86af089',
#     'originalWidth': 1600,
#     'originalHeight': 902,
#     'caption': 'Down market by Artit Wongpradu via Shutterstock',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/YVXIRqHKO9DSNvLWzwD98w--~B/aD05MDI7dz0xNjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/barchart_com_477/504dba31bff02fcd8f8d5c2ba86af089',
#       'width': 1600,
#       'height': 902,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/6aN5dHsTTcY0db.H6uJbPQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/barchart_com_477/504dba31bff02fcd8f8d5c2ba86af089',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Barchart', 'url': 'https://www.barchart.com/'},
#    'canonicalUrl': {'url': 'https://www.barchart.com/story/news/36716069/the-nasdaq-100-etf-just-flashed-a-bearish-chart-signal-heres-what-happens-next',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/nasdaq-100-etf-just-flashed-160923542.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '8baff117-2afd-3a53-8c2b-7786ec263b8b',
#   'content': {'id': '8baff117-2afd-3a53-8c2b-7786ec263b8b',
#    'contentType': 'STORY',
#    'title': 'Dear Western Digital Stock Fans, Mark Your Calendars for Dec. 22',
#    'description': '',
#    'summary': 'Leading digital storage product maker will join the Nasdaq 100 next week.',
#    'pubDate': '2025-12-19T16:00:02Z',
#    'displayTime': '2025-12-19T16:00:02Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/barchart_com_477/a74fe71f49d54d2378c4c210e5af8823',
#     'originalWidth': 1000,
#     'originalHeight': 667,
#     'caption': 'Western Digital Corp_ red hard drives-by Victor Maschek via Shutterstock',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Z87bAfyicZDQaii6q5rSzg--~B/aD02Njc7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/barchart_com_477/a74fe71f49d54d2378c4c210e5af8823',
#       'width': 1000,
#       'height': 667,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/1Eft1Wlno3aUuFrjP0RGdA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/barchart_com_477/a74fe71f49d54d2378c4c210e5af8823',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Barchart', 'url': 'https://www.barchart.com/'},
#    'canonicalUrl': {'url': 'https://www.barchart.com/story/news/36715843/dear-western-digital-stock-fans-mark-your-calendars-for-dec-22',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/dear-western-digital-stock-fans-160002274.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '805475bb-2836-31f0-8dfe-58e429fa95af',
#   'content': {'id': '805475bb-2836-31f0-8dfe-58e429fa95af',
#    'contentType': 'STORY',
#    'title': 'Invesco Unlocks $180 Million Windfall After QQQ Vote Passes',
#    'description': '',
#    'summary': 'Shareholders of the $402 billion Invesco QQQ Trust Series 1 approved changing the fund’s structure from a unit investment trust, which is a little-used structure dating back to the birth of the first exchange-traded funds in the 1990s, an Invesco spokesperson said Friday.  Subject to board approval, Invesco will now lower QQQ’s expense ratio by two basis points to 0.18% given that the item, along with two others, were approved.',
#    'pubDate': '2025-12-19T14:12:59Z',
#    'displayTime': '2025-12-19T14:12:59Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/bloomberg_holding_pen_162/3e45e90928b89e396bb10889fea67a7b',
#     'originalWidth': 2000,
#     'originalHeight': 1332,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/dX7xEA53R2B.yqp64c.a3Q--~B/aD0xMzMyO3c9MjAwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/bloomberg_holding_pen_162/3e45e90928b89e396bb10889fea67a7b',
#       'width': 2000,
#       'height': 1332,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/WV2dckvqbHdsiZC2troO8w--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/bloomberg_holding_pen_162/3e45e90928b89e396bb10889fea67a7b',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Bloomberg',
#     'url': 'https://www.bloomberg.com/company'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/invesco-unlocks-180-million-windfall-141259902.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/invesco-unlocks-180-million-windfall-141259902.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '0dbbf83c-0f92-3c27-a32f-27fbbdbc4b70',
#   'content': {'id': '0dbbf83c-0f92-3c27-a32f-27fbbdbc4b70',
#    'contentType': 'STORY',
#    'title': 'Exchange-Traded Funds Higher, Equity Futures Mixed Pre-Bell Friday Amid Economic Data Releases',
#    'description': '',
#    'summary': 'The broad market exchange-traded fund SPDR S&P 500 ETF Trust (SPY) was up 0.2% and the actively trad',
#    'pubDate': '2025-12-19T13:59:22Z',
#    'displayTime': '2025-12-19T13:59:22Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': None,
#    'provider': {'displayName': 'MT Newswires',
#     'url': 'https://www.mtnewswires.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/exchange-traded-funds-higher-equity-135922082.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/exchange-traded-funds-higher-equity-135922082.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': True,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '4f31f2de-f127-3ce4-aad1-6888959ba4bd',
#   'content': {'id': '4f31f2de-f127-3ce4-aad1-6888959ba4bd',
#    'contentType': 'STORY',
#    'title': 'Oracle TikTok deal lifts AI mining stocks as bitcoin tags $88,000',
#    'description': '',
#    'summary': "Oracle shares jumped 6% in pre-market on Friday as TikTok's U.S. agreement helped calm AI bubble fears after a volatile macro week.",
#    'pubDate': '2025-12-19T11:44:09Z',
#    'displayTime': '2025-12-19T11:44:09Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/coindesk_75/5f3959a935b2ccd2eb18510a4ba35fa3',
#     'originalWidth': 1920,
#     'originalHeight': 1080,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/68K3_9emEC5asgLgXfUPgQ--~B/aD0xMDgwO3c9MTkyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/coindesk_75/5f3959a935b2ccd2eb18510a4ba35fa3',
#       'width': 1920,
#       'height': 1080,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/Ge_jnjqpbgc.36bs23emYA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/coindesk_75/5f3959a935b2ccd2eb18510a4ba35fa3',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'CoinDesk', 'url': 'https://www.coindesk.com'},
#    'canonicalUrl': {'url': 'https://www.coindesk.com/markets/2025/12/19/oracle-tiktok-deal-lifts-ai-mining-stocks-as-bitcoin-tags-usd88-000',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/oracle-tiktok-deal-lifts-ai-114409190.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '6e89fa60-5d29-3a6e-85ea-a0d3de60b3ae',
#   'content': {'id': '6e89fa60-5d29-3a6e-85ea-a0d3de60b3ae',
#    'contentType': 'STORY',
#    'title': 'ETF Fund Flows: IVV Gains $34 Billion Ahead of CPI',
#    'description': '',
#    'summary': '<p>Below are the daily ETF fund flows for December 18, 2025.</p>',
#    'pubDate': '2025-12-18T23:00:05Z',
#    'displayTime': '2025-12-18T23:00:05Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/indexuniverse.com/b28ee8e43fc147e1667f80a2328229cf',
#     'originalWidth': 1254,
#     'originalHeight': 836,
#     'caption': 'Inflation',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ak9bi5DRXPXzmqb8mRwlfQ--~B/aD04MzY7dz0xMjU0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/indexuniverse.com/b28ee8e43fc147e1667f80a2328229cf',
#       'width': 1254,
#       'height': 836,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/G5KKdqXovE.T0iulRnsV0w--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/indexuniverse.com/b28ee8e43fc147e1667f80a2328229cf',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'etf.com', 'url': 'https://www.etf.com/'},
#    'canonicalUrl': {'url': 'http://www.etf.com/sections/daily-etf-flows/etf-fund-flows-ivv-gains-34-billion-ahead-cpi?utm_source=yahoo-finance&utm_medium=rss&utm_campaign=yahoo-finance-rss',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/etf-fund-flows-ivv-gains-230005540.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'be096893-53a5-3c26-aafa-644ba7b1eba3',
#   'content': {'id': 'be096893-53a5-3c26-aafa-644ba7b1eba3',
#    'contentType': 'STORY',
#    'title': 'Exchange-Traded Funds Point Higher as US Equities Rise After Midday',
#    'description': '',
#    'summary': 'Broad Market Indicators Broad-market exchange-traded funds IWM and IVV rose. Actively traded Inve',
#    'pubDate': '2025-12-18T18:09:52Z',
#    'displayTime': '2025-12-18T18:09:52Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': None,
#    'provider': {'displayName': 'MT Newswires',
#     'url': 'https://www.mtnewswires.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/exchange-traded-funds-point-higher-180952390.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/exchange-traded-funds-point-higher-180952390.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': True,
#      'isPremiumFreeNews': False}},
#    'storyline': None}}]

# %%
aapl= yf.Ticker("aapl")
aapl_stock_info = aapl.info

aapl_stock_info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple Vision Pro, Apple TV, Apple Watch, Beats products, and HomePod, as well as Apple branded and third-party accessories. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV, which offers exclusive original content and live sports; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers and resellers. The company was formerly known as Apple Computer, Inc. and changed its name to Apple Inc. in January 2007. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 166000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 63,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2024,
#    'totalPay': 16520856,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 60,
#    'title': 'Senior VP & General Counsel',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 5022182,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 57,
#    'title': 'Senior Vice President of Retail & People',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'totalPay': 5022182,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kevan  Parekh',
#    'age': 52,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Sabih  Khan',
#    'title': 'Chief Operating Officer',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Kondo',
#    'title': 'Senior Director of Corporate Accounting',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kristin Huguet Quayle',
#    'title': 'Vice President of Worldwide Communications',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Adrian  Perica',
#    'age': 50,
#    'title': 'Vice President of Corporate Development',
#    'yearBorn': 1974,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 7,
#  'boardRisk': 1,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1764547200,
#  'compensationAsOfEpochDate': 1735603200,
#  'irWebsite': 'http://investor.apple.com/',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 272.19,
#  'open': 272.145,
#  'dayLow': 269.9,
#  'dayHigh': 274.5763,
#  'regularMarketPreviousClose': 272.19,
#  'regularMarketOpen': 272.145,
#  'regularMarketDayLow': 269.9,
#  'regularMarketDayHigh': 274.5763,
#  'dividendRate': 1.04,
#  'dividendYield': 0.38,
#  'exDividendDate': 1762732800,
#  'payoutRatio': 0.1367,
#  'fiveYearAvgDividendYield': 0.53,
#  'beta': 1.107,
#  'trailingPE': 36.63588,
#  'forwardPE': 30.003498,
#  'volume': 111198501,
#  'regularMarketVolume': 111198501,
#  'averageVolume': 48556695,
#  'averageVolume10days': 51065060,
#  'averageDailyVolume10Day': 51065060,
#  'bid': 272.0,
#  'ask': 274.97,
#  'bidSize': 1,
#  'askSize': 4,
#  'marketCap': 4061369729024,
#  'fiftyTwoWeekLow': 169.21,
#  'fiftyTwoWeekHigh': 288.62,
#  'allTimeHigh': 288.62,
#  'allTimeLow': 0.049107,
#  'priceToSalesTrailing12Months': 9.7591305,
#  'fiftyDayAverage': 269.5178,
#  'twoHundredDayAverage': 229.9118,
#  'trailingAnnualDividendRate': 1.02,
#  'trailingAnnualDividendYield': 0.0037473822,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 4101524422656,
#  'profitMargins': 0.26915002,
#  'floatShares': 14750642146,
#  'sharesOutstanding': 14776353000,
#  'sharesShort': 129458559,
#  'sharesShortPriorMonth': 115557836,
#  'sharesShortPreviousMonthDate': 1761868800,
#  'dateShortInterest': 1764288000,
#  'sharesPercentSharesOut': 0.0088,
#  'heldPercentInsiders': 0.016970001,
#  'heldPercentInstitutions': 0.64406997,
#  'shortRatio': 2.64,
#  'shortPercentOfFloat': 0.0088,
#  'impliedSharesOutstanding': 14840390000,
#  'bookValue': 4.991,
#  'priceToBook': 54.8327,
#  'lastFiscalYearEnd': 1758931200,
#  'nextFiscalYearEnd': 1790467200,
#  'mostRecentQuarter': 1758931200,
#  'earningsQuarterlyGrowth': 0.864,
#  'netIncomeToCommon': 112010002432,
#  'trailingEps': 7.47,
#  'forwardEps': 9.12127,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 9.856,
#  'enterpriseToEbitda': 28.336,
#  '52WeekChange': 0.07208049,
#  'SandP52WeekChange': 0.14402747,
#  'lastDividendValue': 0.26,
#  'lastDividendDate': 1762732800,
#  'quoteType': 'EQUITY',
#  'currentPrice': 273.67,
#  'targetHighPrice': 350.0,
#  'targetLowPrice': 215.0,
#  'targetMeanPrice': 287.70682,
#  'targetMedianPrice': 300.0,
#  'recommendationMean': 2.0,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 41,
#  'totalCash': 54697000960,
#  'totalCashPerShare': 3.702,
#  'ebitda': 144748003328,
#  'totalDebt': 112377004032,
#  'quickRatio': 0.771,
#  'currentRatio': 0.893,
#  'totalRevenue': 416161005568,
#  'debtToEquity': 152.411,
#  'revenuePerShare': 27.84,
#  'returnOnAssets': 0.22964,
#  'returnOnEquity': 1.7142199,
#  'grossProfits': 195201007616,
#  'freeCashflow': 78862254080,
#  'operatingCashflow': 111482003456,
#  'earningsGrowth': 0.912,
#  'revenueGrowth': 0.079,
#  'grossMargins': 0.46905,
#  'ebitdaMargins': 0.34782,
#  'operatingMargins': 0.31647,
#  'financialCurrency': 'USD',
#  'symbol': 'AAPL',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'corporateActions': [],
#  'postMarketTime': 1766192389,
#  'regularMarketTime': 1766178000,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_24937',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'marketState': 'CLOSED',
#  'fiftyTwoWeekChangePercent': 7.2080493,
#  'dividendDate': 1762992000,
#  'earningsTimestamp': 1761854400,
#  'earningsTimestampStart': 1769720400,
#  'earningsTimestampEnd': 1769720400,
#  'earningsCallTimestampStart': 1761858000,
#  'earningsCallTimestampEnd': 1761858000,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 7.47,
#  'epsForward': 9.12127,
#  'epsCurrentYear': 8.22807,
#  'priceEpsCurrentYear': 33.260536,
#  'fiftyDayAverageChange': 4.1522217,
#  'fiftyDayAverageChangePercent': 0.015406113,
#  'twoHundredDayAverageChange': 43.75821,
#  'twoHundredDayAverageChangePercent': 0.19032606,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '2.0 - Buy',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'regularMarketChangePercent': 0.543742,
#  'regularMarketPrice': 273.67,
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 345479400000,
#  'postMarketChangePercent': -0.20828271,
#  'postMarketPrice': 273.1,
#  'postMarketChange': -0.5700073,
#  'regularMarketChange': 1.48001,
#  'regularMarketDayRange': '269.9 - 274.5763',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 48556695,
#  'fiftyTwoWeekLowChange': 104.46001,
#  'fiftyTwoWeekLowChangePercent': 0.61733943,
#  'fiftyTwoWeekRange': '169.21 - 288.62',
#  'fiftyTwoWeekHighChange': -14.949982,
#  'fiftyTwoWeekHighChangePercent': -0.05179815,
#  'displayName': 'Apple',
#  'trailingPegRatio': 2.7695}

# %%
goog = yf.Ticker("GOOG")
goog_stock_info = goog.info

set(aapl_stock_info.keys()).difference(set(goog_stock_info.keys()))
# Out:
# {'auditRisk',
#  'boardRisk',
#  'compensationRisk',
#  'fiveYearAvgDividendYield',
#  'governanceEpochDate',
#  'irWebsite',
#  'overallRisk',
#  'shareHolderRightsRisk',
#  'shortPercentOfFloat'}

# %%
aapl_historical = aapl.history(start="2020-06-02", end="2020-06-07", interval="1m")
aapl_historical
# Out:
# $AAPL: possibly delisted; no price data found  (1m 2020-06-02 -> 2020-06-07) (Yahoo error = "1m data not available for startTime=1591070400 and endTime=1591502400. The requested range must be within the last 30 days.")
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.earnings_estimate
# Out:
#             avg   low  high  yearAgoEps  numberOfAnalysts  growth
# period
# 0q      1.75840  1.63  1.82     0.97000                26  0.8128
# +1q     2.46401  2.29  2.67     2.40000                22  0.0267
# 0y      7.38321  7.25  7.47     6.08000                35  0.2143
# +1y     7.94575  7.13  9.00     7.38321                38  0.0762

# %%
result = aapl.get_earnings_estimate()
print(result)
# Out:
#             avg   low  high  yearAgoEps  numberOfAnalysts  growth
# period
# 0q      1.75840  1.63  1.82     0.97000                26  0.8128
# +1q     2.46401  2.29  2.67     2.40000                22  0.0267
# 0y      7.38321  7.25  7.47     6.08000                35  0.2143
# +1y     7.94575  7.13  9.00     7.38321                38  0.0762
